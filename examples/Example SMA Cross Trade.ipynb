# %% [markdown]
# ## <font color='orange'><b>Import libraries</b></font>

# %%
# Import this library
from nbacktest import Backtest, Strategy

# Import other libraries
import yfinance as yf
import quantstats as qs

import numpy as np

# %% [markdown]
# ## <font color='orange'><b>Create Strategy</b></font>

# %%
class TestStrategy (Strategy):

    def on_start(self):

        print("Strategy started!")

        self.data.loc[:, "Signal"] = np.nan

        print(self.data)
        self.current_trade = None


    def on_end(self):
        """"
        This function is called when the backtest of all candles is finished
        """
        print("Strategy finished!")


    def next(self):
        """"
        This function is called every candle (iteration)
        """

        sma7 = self.data["SMA 7"]["GOOG"] # Pandas serie
        sma21 = self.data["SMA 21"]["GOOG"] # Pandas serie

        current_price = self.close["GOOG"][-1]
        investment = 0.8*self.broker.equity
        quantity = int(investment/current_price)
        
        if sma7[-2] < sma21[-2] and sma7[-1] > sma21[-1]:

            if self.current_trade is not None:
                self.current_trade.close()

            order = self.buy("GOOG", quantity)
            self.current_trade = self.create_trade(orders=[order], description="Long on GOOG")
            self.data.loc[-1, "Signal"] = 1


        elif sma7[-2] > sma21[-2] and sma7[-1] < sma21[-1]:

            if self.current_trade is not None:
                self.current_trade.close()

            order = self.sell("GOOG", quantity)
            self.current_trade = self.create_trade(orders=[order], description="Short on GOOG")
            self.data.loc[-1, "Signal"] = -1

# %% [markdown]
# ## <font color='orange'><b>Backtest Configuration</b></font>

# %%
universe = ["GOOG"] # List containing the tickers of all the assets you are backtesting

ohlc = yf.download(universe, start="2018-01-01", end="2023-01-01", interval="1d") # Download OHLC data from Yahoo Finance

ohlc.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2022-12-23  87.620003  90.099998  87.620003  89.809998  89.809998  17815000
# 2022-12-27  89.309998  89.500000  87.535004  87.930000  87.930000  15470900
# 2022-12-28  87.500000  88.519997  86.370003  86.459999  86.459999  17879600
# 2022-12-29  87.029999  89.364998  86.989998  88.949997  88.949997  18280700
# 2022-12-30  87.364998  88.830002  87.029999  88.730003  88.730003  19190300

# %% [markdown]
# ## <font color='orange'><b>Create Simple Moving Averages</b></font>

# %%
for n in [7, 21]:
    ohlc["SMA %s" % n] = ohlc["Close"].rolling(n).mean()

ohlc.tail()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2022-12-23  87.620003  90.099998  87.620003  89.809998  89.809998  17815000
# 2022-12-27  89.309998  89.500000  87.535004  87.930000  87.930000  15470900
# 2022-12-28  87.500000  88.519997  86.370003  86.459999  86.459999  17879600
# 2022-12-29  87.029999  89.364998  86.989998  88.949997  88.949997  18280700
# 2022-12-30  87.364998  88.830002  87.029999  88.730003  88.730003  19190300
#
#                 SMA 7     SMA 21
# Date
# 2022-12-23  89.879999  94.575237
# 2022-12-27  89.412857  94.114761
# 2022-12-28  88.784285  93.648571
# 2022-12-29  88.755713  93.339523
# 2022-12-30  88.627143  92.733809

# %% [markdown]
# ## <font color='orange'><b>Run Backtest</b></font>

# %%
bt = Backtest(data=ohlc, universe=universe, strategy=TestStrategy, cash=10_000)

result = bt.run()

print("---------------------------")
print("Final balance: %.2f" % bt.broker.balance)
print("Final equity: %.2f" % bt.broker.equity)

bt.broker.orderbook
# Out:
# Converting data to multi index!
# Strategy started!
#               Open    High        Low  Close Adj Close    Volume SMA 7 SMA 21  \
#               GOOG    GOOG       GOOG   GOOG      GOOG      GOOG  GOOG   GOOG
# Date
# 2018-01-02  52.417  53.347  52.261501  53.25     53.25  24752000   NaN    NaN
#
#            Signal
#
# Date
# 2018-01-02    NaN
# Strategy finished!
# ---------------------------
# Final balance: 14245.83
# Final equity: 8212.19
#      iteration action ticker  quantity      price  commission  slippage  \
# id
# 0           24   sell   GOOG    -148.0  54.029999           0         0
# 1           37    buy   GOOG     148.0  57.187500           0         0
# 2           37    buy   GOOG     133.0  57.187500           0         0
# 3           55   sell   GOOG    -133.0  52.453999           0         0
# 4           55   sell   GOOG    -135.0  52.453999           0         0
# ..         ...    ...    ...       ...        ...         ...       ...
# 128       1215   sell   GOOG     -69.0  96.580002           0         0
# 129       1229    buy   GOOG      69.0  98.500000           0         0
# 130       1229    buy   GOOG      67.0  98.500000           0         0
# 131       1244   sell   GOOG     -67.0  93.070000           0         0
# 132       1244   sell   GOOG     -68.0  93.070000           0         0
#
#            total
# id
# 0    7996.439819
# 1   -8463.750000
# 2   -7605.937500
# 3    6976.381809
# 4    7081.289806
# ..           ...
# 128  6664.020126
# 129 -6796.500000
# 130 -6599.500000
# 131  6235.689980
# 132  6328.759979
#
# [133 rows x 8 columns]

# %%
bt.broker.positions
# Out:
#         quantity  commission  slippage  total_invested        value
# ticker
# GOOG       -68.0           0         0     4245.832588 -6033.640228

# %%
bt.statistics()
# Out:
# {'n_won': 21,
#  'n_lost': 45,
#  'n_total': 66,
#  'win_rate': 0.3181818181818182,
#  'avg_abs_return': -31.55950592503403,
#  'avg_abs_return_per_win': 469.93237395513626,
#  'avg_abs_return_per_lost': -265.5890498691135}

# %%
#result[("BUY","GOOG")] = np.nan
#result[("SELL", "GOOG")] = np.nan

#result.loc[:,("BUY","GOOG")][ (result[("SMA 7", "GOOG")].shift(1) < result[("SMA 21", "GOOG")].shift(1)) & (result[("SMA 7", "GOOG")] > result[("SMA 21", "GOOG")]) ] = result[("Adj Close", "GOOG")]/result[("Adj Close", "GOOG")][0]

#result.loc[:,("SELL", "GOOG")][ (result[("SMA 7", "GOOG")].shift(1) > result[("SMA 21", "GOOG")].shift(1)) & (result[("SMA 7", "GOOG")] < result[("SMA 21", "GOOG")]) ] = result[("Adj Close", "GOOG")]/result[("Adj Close", "GOOG")][0]

#result.head()

# %%
#%matplotlib qt5
# %matplotlib inline

import matplotlib.pyplot as plt
plt.plot(result["_equity"]/result["_equity"][0], label="Equity")
plt.plot(result[("SMA 7", "GOOG")]/result[("SMA 7", "GOOG")][6], label="SMA 7")
plt.plot(result[("SMA 21", "GOOG")]/result[("SMA 21", "GOOG")][20], label="SMA 21")
plt.plot(result[("Adj Close", "GOOG")]/result[("Adj Close", "GOOG")][0], label="GOOG")
plt.plot(result[("BUY", "GOOG")], 'go', label="BUY")
plt.plot(result[("SELL", "GOOG")], 'ro', label="SELL")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\nineb\anaconda3\envs\quant\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\nineb\anaconda3\envs\quant\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\nineb\anaconda3\envs\quant\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BUY'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\nineb\anaconda3\envs\quant\lib\site-packages\pandas\_libs\index.pyx:774, in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# File c:\Users\nineb\anaconda3\envs\quant\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#
# KeyError: 'BUY'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\nineb\Documents\Repositories\n-backtest\examples\Example SMA Cross Trade.ipynb Cell 14 in 9
#       <a href='vscode-notebook-cell:/c%3A/Users/nineb/Documents/Repositories/n-backtest/examples/Example%20SMA%20Cross%20Trade.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a> plt.plot(result[("SMA 21", "GOOG")]/result[("SMA 21", "GOOG")][20], label="SMA 21")
#       <a href='vscode-notebook-cell:/c%3A/Users/nineb/Documents/Repositories/n-backtest/examples/Example%20SMA%20Cross%20Trade.ipynb#X16sZmlsZQ%3D%3D?line=7'>8</a> plt.plot(result[("Adj Close", "GOOG")]/result[("Adj Close", "GOOG")][0], label="GOOG")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/nineb/Documents/Repositories/n-backtest/examples/Example%20SMA%20Cross%20Trade.ipynb#X16sZmlsZQ%3D%3D?line=8'>9</a> plt.plot(result[("BUY", "GOOG")], 'go', label="BUY")
#      <a href='vscode-notebook-cell:/c%3A/Users/nineb/Documents/Repositories/n-backtest/examples/Example%20SMA%20Cross%20Trade.ipynb#X16sZmlsZQ%3D%3D?line=9'>10</a> plt.plot(result[("SELL", "GOOG")], 'ro', label="SELL")
#      <a href='vscode-notebook-cell:/c%3A/Users/nineb/Documents/Repositories/n-backtest/examples/Example%20SMA%20Cross%20Trade.ipynb#X16sZmlsZQ%3D%3D?line=10'>11</a> plt.legend()
#
# File c:\Users\nineb\anaconda3\envs\quant\lib\site-packages\pandas\core\frame.py:3804, in DataFrame.__getitem__(self, key)
#    3802 if is_single_key:
#    3803     if self.columns.nlevels > 1:
# -> 3804         return self._getitem_multilevel(key)
#    3805     indexer = self.columns.get_loc(key)
#    3806     if is_integer(indexer):
#
# File c:\Users\nineb\anaconda3\envs\quant\lib\site-packages\pandas\core\frame.py:3855, in DataFrame._getitem_multilevel(self, key)
#    3853 def _getitem_multilevel(self, key):
#    3854     # self.columns is a MultiIndex
# -> 3855     loc = self.columns.get_loc(key)
#    3856     if isinstance(loc, (slice, np.ndarray)):
#    3857         new_columns = self.columns[loc]
#
# File c:\Users\nineb\anaconda3\envs\quant\lib\site-packages\pandas\core\indexes\multi.py:2927, in MultiIndex.get_loc(self, key, method)
#    2925 if keylen == self.nlevels and self.is_unique:
#    2926     try:
# -> 2927         return self._engine.get_loc(key)
#    2928     except TypeError:
#    2929         # e.g. test_partial_slicing_with_multiindex partial string slicing
#    2930         loc, _ = self.get_loc_level(key, list(range(self.nlevels)))
#
# File c:\Users\nineb\anaconda3\envs\quant\lib\site-packages\pandas\_libs\index.pyx:777, in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# KeyError: ('BUY', 'GOOG')

# %% [markdown]
# ## <font color='orange'><b>Performance Report from QuantStats</b></font>

# %%
qs.reports.basic(returns=result["_equity"], benchmark="SPY", rf=0.00)
#qs.reports.html(returns=result["Equity"], benchmark="SPY", rf=0.00, title="TestStrategy")
# Out:
# <h4>Performance Metrics</h4>
#                     Strategy    Benchmark
# ------------------  ----------  -----------
# Start Period        2018-01-02  2018-01-02
# End Period          2022-12-30  2022-12-30
# Risk-Free Rate      0.0%        0.0%
# Time in Market      99.0%       100.0%
#
# Cumulative Return   -17.88%     54.98%
# CAGR﹪              -3.87%      9.17%
#
# Sharpe              -0.05       0.52
# Prob. Sharpe Ratio  45.42%      87.29%
# Sortino             -0.07       0.71
# Sortino/√2          -0.05       0.5
# Omega               0.99        0.99
#
# Max Drawdown        -33.64%     -33.72%
# Longest DD Days     1785        360
#
# Gain/Pain Ratio     -0.01       0.1
# Gain/Pain (1M)      -0.05       0.53
#
# Payoff Ratio        0.91        0.9
# Profit Factor       0.99        1.1
# Common Sense Ratio  1.04        0.93
# CPC Index           0.45        0.54
# Tail Ratio          1.05        0.85
# Outlier Win Ratio   3.67        4.36
# Outlier Loss Ratio  3.62        4.15
#
# MTD                 -3.14%      -5.76%
# 3M                  -6.89%      5.9%
# 6M                  -0.23%      1.43%
# YTD                 -12.39%     -18.18%
# 1Y                  -13.25%     -18.61%
# 3Y (ann.)           0.21%       7.3%
# 5Y (ann.)           -3.93%      8.05%
# 10Y (ann.)          -3.87%      9.17%
# All-time (ann.)     -3.87%      9.17%
#
# Avg. Drawdown       -33.64%     -2.15%
# Avg. Drawdown Days  1785        18
# Recovery Factor     -0.53       1.63
# Ulcer Index         0.2         0.09
# Serenity Index      -0.04       0.51
# <h4>Strategy Visualization</h4>
# c:\Users\nineb\anaconda3\envs\quant\lib\site-packages\quantstats\stats.py:968: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   returns = returns.pivot('Year', 'Month', 'Returns').fillna(0)

# %%
import pandas as pd

#df = pd.DataFrame(data={"a":[1,2,3,4,5]})
df = pd.DataFrame()

df.loc[:,"b"] = [15,20,25,30]

df.head()
# Out:
#     b
# 0  15
# 1  20
# 2  25
# 3  30

# %%
df[0:0+1]
# Out:
#     b
# 0  15

# %%
test = df.iloc[0:0+1]

test.head()
# Out:
#     b
# 0  15
